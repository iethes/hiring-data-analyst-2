# %%
# %pip install ipython-sql
# %load_ext sql

import pandas as pd
import random
import sqlite3
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("/content/beauty_brand_gmv.db")
df = pd.read_sql("SELECT * FROM beauty_brand_gmv;", conn)

# %% [markdown]
# ## Task 1: Growth Rate Analysis
#
# Write a query to calculate the GMV growth rate (%) for each brand compared to the previous month. Display only the records where a brand's growth rate exceeds the average growth rate of all brands for that month.

# %%
pd.read_sql("""

# write your answer here

""", conn)

# %% [markdown]
# ## Task 2: Sub-category Dominance per Brand
#
# Create a query to identify the sub-category with the highest GMV share for each brand, based on its total GMV in 2024.

# %%
pd.read_sql("""

# write your answer here

""", conn)
# Out:
#         brand sub_category   total_gmv  contribution_percentage
# 0  Maybelline    Concealer  3237551628                    62.33
# 1   Make Over        Blush  2713417525                    73.73
# 2   Somethinc        Blush  2569865633                    58.27
# 3         NYX    Concealer  2540035914                    74.35
# 4      Wardah        Blush  2372155488                    64.44
# 5      Revlon   Foundation  2238742884                    58.21
# 6   Focallure  Highlighter  1781287531                    43.43
# 7     Hanasui       Powder  1760449661                    49.67
# 8       Emina    Concealer   987151809                    38.35
# 9      LT Pro  Highlighter   923376773                    26.20

# %% [markdown]
# # Task 3: Identify the Month When a Brand Reaches 50% of Its Annual GMV
#
# Create a query to determine the first month in which each brand’s cumulative GMV exceeds 50% of its total annual GMV for 2024.

# %%
pd.read_sql("""

# write your answer here

""", conn)

# %% [markdown]
# # Task 4: Visualization of Brand GMV Share by Month

# %% [markdown]
# Create a trend line chart to visualize how each brand’s GMV share changes over time (month-year).
#
#
# You may use any Python data visualization library but not limited to, such as:
#
# - Matplotlib
# - Seaborn
# - Plotly

# %%
df = pd.read_sql("""
    SELECT brand, month, gmv
    FROM beauty_brand_gmv
    WHERE strftime('%Y', month) = '2024'
""", conn)


# write your answer here

# %% [markdown]
# # Task 5: Brand Refinement Performance Analysis
#
# 📌 For this task, you will use the data from brand_refinement.csv.
#
#
# Evaluate the effectiveness of two brand standardization methods (Method A & Method B) by comparing their results against AI-detected brand names. The goal is to determine which method produces the most accurate refinements.
#
# Compare Brand Standardization Accuracy:
#
# - Evaluate Method A (column_B) and Method B (column_C) by comparing them to the AI-detected brand (column_A).
# - Create two validation columns:
#   - check_B → True if Method A's brand name (column_B) matches column_A, False
#    otherwise.
#   - check_C → True if Method B's brand name (column_C) matches column_A, False otherwise.
# -  Matching Criteria:
#   The comparison should ignore minor variations, including:
#
#   - Letter case differences (e.g., L'ORÉAL vs. l'oreal)
#   - Spacing inconsistencies (e.g., Bio Talk vs. Biotalk)
#   - Punctuation differences (e.g., D’alba vs. D'alba)
#   - Trivial suffixes (e.g., Ltd, Inc., + if they do not change the brand identity)
#
# - Analyze Method Performance:
# Calculate the percentage of correct matches for both Method A and Method B.
# Determine which method performs better based on accuracy.

# %%
# write your answer here

# %%
conn.close()
